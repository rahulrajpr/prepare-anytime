# %%
from pyspark.sql.function import *
from pyspark.sql.types import *
from pyspark.sql import SparkSession
# Out:
# Running cells with 'env (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/systemd/Desktop/prepare-anytime/env/bin/python -m pip install ipykernel -U --force-reinstall'
